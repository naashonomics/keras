# %%
import numpy as np
# %matplotlib inline
import os
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_circles

# %%
x,y = make_circles(n_samples=1000,noise=0.1,factor=0.2,random_state=0)
x
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
x.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5,5))
plt.figure(figsize=(5, 5))
plt.plot(x[y==0, 0], x[y==0, 1], 'ob', alpha=0.5)
plt.plot(x[y==1, 0], x[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])
model.fit(x, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 0s 279us/step - loss: 0.6925 - acc: 0.5900
# Epoch 2/20
# 1000/1000 [==============================] - 0s 49us/step - loss: 0.6581 - acc: 0.7120
# Epoch 3/20
# 1000/1000 [==============================] - 0s 45us/step - loss: 0.5929 - acc: 0.8410
# Epoch 4/20
# 1000/1000 [==============================] - 0s 39us/step - loss: 0.5032 - acc: 0.8470
# Epoch 5/20
# 1000/1000 [==============================] - 0s 44us/step - loss: 0.4187 - acc: 0.8660
# Epoch 6/20
# 1000/1000 [==============================] - 0s 45us/step - loss: 0.3540 - acc: 0.8790
# Epoch 7/20
# 1000/1000 [==============================] - 0s 45us/step - loss: 0.2812 - acc: 0.9070
# Epoch 8/20
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.2194 - acc: 0.9500
# Epoch 9/20
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.1739 - acc: 0.9860
# Epoch 10/20
# 1000/1000 [==============================] - 0s 42us/step - loss: 0.1424 - acc: 1.0000
# Epoch 11/20
# 1000/1000 [==============================] - 0s 42us/step - loss: 0.1194 - acc: 1.0000
# Epoch 12/20
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.1020 - acc: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s 47us/step - loss: 0.0885 - acc: 1.0000
# Epoch 14/20
# 1000/1000 [==============================] - 0s 49us/step - loss: 0.0778 - acc: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s 51us/step - loss: 0.0693 - acc: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s 60us/step - loss: 0.0624 - acc: 1.0000
# Epoch 17/20
# 1000/1000 [==============================] - 0s 47us/step - loss: 0.0566 - acc: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.0517 - acc: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s 42us/step - loss: 0.0475 - acc: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s 46us/step - loss: 0.0442 - acc: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(x[y==0, 0], x[y==0, 1], 'ob', alpha=0.5)
plt.plot(x[y==1, 0], x[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
